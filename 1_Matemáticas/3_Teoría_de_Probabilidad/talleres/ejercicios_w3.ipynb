# %%
1/(10)
# Out:
# 0.1

# %%
((56 - 50)/10) - ((52 - 50)/10)
# Out:
# 0.39999999999999997

# %% [markdown]
# # Distribución normal

# %% [markdown]
# * Punto 1:
#
# Pregunta 1
# La distribución normal como parte de las distribuciones continuas de mayor aplicación, describe el comportamiento de gran cantidad de experimentos aleatorios desarrollados en espacios muestrales grandes, generalmente con un número de ensayos superior a 30. Razón por la cual, por medio de la consideración de un caso particular en el cual los resultados siguen una distribución normal, se pretende que logres afianzar los conocimientos necesarios a la hora de estandarizar una distribución normal y realizar los cálculos asociados a las probabilidades de dicho evento.
#
# EL GRE ó Graduate Record Examination es un examen estandarizado requerido en el proceso de admisión de un gran número de postgrados en todo el mundo.  Este examen evalúa la capacidad de escritura y redacción, el conocimiento en matemáticas básicas (aritmética, álgebra, problemas matemáticos y geometría), matemáticas avanzadas (estadística, probabilidad, combinaciones y permutaciones) e interpretación y análisis de datos.
#
# El resultado del test para un estudiante seleccionado al azar es una variable aleatoria que sigue una distribución Normal de media igual a 152 puntos y desviación estándar igual a 6 puntos.
#
#
# ¿Qué porcentaje de personas obtienen una calificación inferior o igual a 152 puntos en el GRE?

# %%
import scipy.stats as stats

# Parámetros de la distribución normal
media = 152
sigma = 6

# Calculamos la probabilidad de obtener una calificación inferior o igual a 152

p = stats.norm.cdf(152, loc=media, scale=sigma)
porcentaje = p * 100
print('El porcentaje de calificaciones a 152 es =', porcentaje)
# Out:
# El porcentaje de calificaciones a 152 es = 50.0

# %% [markdown]
# * Punto 2
#
# Pregunta 2
# Algunas de las universidades más prestigiosas de Estados Unidos tienen como requisito de admisión a sus posgrados un resultado mínimo de 162 puntos en el GRE. ¿Qué porcentaje de estudiantes cumple con este requisito?

# %%
import scipy.stats as stats 

# Parámetros de la distribución normal
media = 152
sigma = 6

# Calculamos la probabilidad de obtener una calificación inferior o igual a 152
p = stats.norm.cdf(162, loc=media, scale=sigma)
p_pasar = 1 - p
porcentaje = p_pasar * 100
print('El porcentaje admitidos es =', porcentaje)
# Out:
# El porcentaje admitidos es = 4.77903522728147

# %% [markdown]
# * punto 3
#
# ¿Qué proporción de estudiantes que toman el GRE obtiene puntajes entre 145 y 155 puntos?

# %%
import scipy.stats as stats 

# Parámetros de la distribución normal
media = 152
sigma = 6

# Calculamos la probabilidad las probabilidades de ambos valores extremos del rango de interés
p_a = stats.norm.cdf(145, loc=media, scale=sigma)
p_b = stats.norm.cdf(155, loc=media, scale=sigma)
p_rango_interes = p_b - p_a
porcentaje = p_rango_interes * 100
print('El porcentaje admitidos es =', porcentaje)
# Out:
# El porcentaje admitidos es = 56.97899566996318

# %% [markdown]
# # Distribución Exponencial

# %% [markdown]
# * punto 1
#
# Desarrolla este cuestionario con el fin de afianzar conocimientos en torno a la obtención de los parámetros relevantes en el cálculo de probabilidades en distribuciones exponenciales. Así como también, las diferencias y similitudes entre esta distribución y la distribución discreta Poisson.
#
# Al call – center de una empresa de telecomunicaciones, llegan llamadas siguiendo un proceso de Poisson. Por lo tanto, el tiempo en minutos, entre dos llamadas consecutivas se puede representar como una variable aleatoria
# 𝑋 que sigue una distribución Exponencial con media de 3 minutos.
#
# ¿Cuál de las siguientes definiciones sobre las variables aleatorias es verdadera?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

# Parámetros de la distribución exponencial
media = 3
lambda_param = 1 / media

# Definir un rango de valores para X
x = np.linspace(0, 15, 100)

# Calcular la función de densidad de probabilidad (PDF)
pdf = expon.pdf(x, scale=media)

# Graficar la PDF
plt.plot(x, pdf, label=f'Exponencial PDF (media = {media} minutos)')
plt.xlabel('Tiempo entre llamadas (minutos)')
plt.ylabel('Densidad de probabilidad')
plt.title('Distribución Exponencial')
plt.legend()
plt.grid(True)
plt.show()

# Definiciones de variables aleatorias
definiciones = [
    f"La variable aleatoria X sigue una distribución Exponencial con media de {media} minutos.",
    f"El parámetro lambda de la distribución Exponencial es {lambda_param}.",
    f"La función de densidad de probabilidad (PDF) de X es f(x) = {lambda_param} * e^(-{lambda_param} * x)."
]

definiciones
# Out:
# ['La variable aleatoria X sigue una distribución Exponencial con media de 3 minutos.',
#  'El parámetro lambda de la distribución Exponencial es 0.3333333333333333.',
#  'La función de densidad de probabilidad (PDF) de X es f(x) = 0.3333333333333333 * e^(-0.3333333333333333 * x).']

# %% [markdown]
# * Punto 2
#
# ¿Cuál es el valor del parámetro λ de la distribución Exponencial asociada a la variable aleatoria
# 𝑋?

# %%
# Parámetros de la distribución exponencial
media = 3
lambda_param = 1 / media
lambda_param
# Out:
# 0.3333333333333333

# %% [markdown]
# * Punto 3
#
# Pregunta 3
# ¿Cuál es la probabilidad de que el tiempo entre dos llamadas consecutivas sea menor a 10 minutos?

# %%
import math 

# Parametros de la distribución exponencial
media = 3
lambda_ = 1 / media 

# Tiempo para el calculo de p
tiempo = 10

# Calculo de P 
p_cdf = 1 - math.exp(-lambda_ * tiempo)
print(f"La probabilidad de que el tiempo entre dos llamadas consecutivas sea menor a 10 minutos es: {p_cdf:.4f}")
# Out:
# La probabilidad de que el tiempo entre dos llamadas consecutivas sea menor a 10 minutos es: 0.9643

# %% [markdown]
# * Punto 4
#
# Si la última llamada que entró al call-center fue hace 6 minutos, ¿cuál es la probabilidad de que la siguiente llamada entre al call-center después de 8 minutos?

# %%
import math

# Parámetro de la distribución exponencial
media = 3
lambda_ = 1 / media

# Tiempo para el cálculo de la probabilidad
tiempo = 8

# Cálculo de la probabilidad
probabilidad = math.exp(-lambda_ * tiempo)
print(f"La probabilidad de que la siguiente llamada entre al call-center después de 8 minutos es: {probabilidad:.4f}")
# Out:
# La probabilidad de que la siguiente llamada entre al call-center después de 8 minutos es: 0.0695

# %% [markdown]
# * Punto 5
#
# Si la última llamada que entró al call-center fue hace 12 minutos, ¿cuál es la probabilidad de que la siguiente llamada entre al call-center en exactamente de 4 minutos?

# %%
import math

# Parámetro de la distribución exponencial
media = 3
lambda_ = 1 / media

# Tiempo para el cálculo de la probabilidad
tiempo = 4

# Cálculo de la probabilidad
probabilidad = math.exp(-lambda_ * tiempo)
print(f"La probabilidad de que la siguiente llamada entre al call-center después de 8 minutos es: {probabilidad:.4f}")
# Out:
# La probabilidad de que la siguiente llamada entre al call-center después de 8 minutos es: 0.2636

# %% [markdown]
# * Punto 6
#
# ¿Cuál es la probabilidad de que en los siguientes 5 minutos entren 3 llamadas al call-center?

# %%
import math

# Parámetro de la distribución de Poisson
lambda_poisson = 5 / 3

# Número de llamadas
k = 3

# Cálculo de la probabilidad usando la fórmula de Poisson
probabilidad = (math.exp(-lambda_poisson) * (lambda_poisson ** k)) / math.factorial(k)
print(f"La probabilidad de que entren exactamente 3 llamadas en los siguientes 5 minutos es: {probabilidad:.4f}")
# Out:
# La probabilidad de que entren exactamente 3 llamadas en los siguientes 5 minutos es: 0.1457
